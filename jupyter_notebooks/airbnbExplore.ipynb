# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

pd.set_option('display.max_columns', None)

# %%
def clean_listings(df):
    str_cols = ['bathrooms_text', 'price', 'room_type', 'property_type', 'neighbourhood_cleansed', 'name']
    irrelevant_cols = ['scrape_id', 'neighbourhood_group_cleansed', 'calendar_updated', 'license', 'bathrooms']
    
    numeric_df = df.copy().select_dtypes(include=np.number)
    numeric_df[str_cols] = df[str_cols]
    filtered_df = numeric_df.drop(columns=irrelevant_cols, axis=1, errors='ignore')
    
    return filtered_df[filtered_df.columns[::-1]]

# %%
# change paths to csv files on your local machine
# download large listings.csv.gz files
amf_df = clean_listings(pd.read_csv('../../GroupCW/amsterdam_data/listings_1.csv'))
atf_df = clean_listings(pd.read_csv('../../GroupCW/athens_data/listings.csv'))
ldn_df = clean_listings(pd.read_csv('../../GroupCW/london_data/listings.csv'))

# %%
report = ProfileReport(amf_df)
# Uncomment the following line to generate a pandas profile report (it might take some time with large datasets)
# report

# %%
ldn_df
# Out:
#                                                     name  \
# 0             Arty and Bright London Apartment in Zone 2
# 1                    Holiday London DB Room Let-on going
# 2                    Bright Chelsea  Apartment. Chelsea!
# 3                  Superb 3-Bed/2 Bath & Wifi: Trendy W1
# 4      Boutique Chelsea/Fulham Double bed 5-star ensuite
# ...                                                  ...
# 76614            Luxury apartment with balcony in Hayes.
# 76615                      BRAND NEW- The Pop Art House!
# 76616  Radiant & Modern 1 BDR Apt w/Private Decked Ga...
# 76617                                    Greenland Villa
# 76618                    Luxury En-Suite in North London
#
#        neighbourhood_cleansed                      property_type  \
# 0                     Lambeth                   Entire apartment
# 1                   Islington          Private room in apartment
# 2      Kensington and Chelsea                   Entire apartment
# ...

# %%
df = pd.read_csv('../../GroupCW/london_data/listings.csv')
df
# Out:
#              id                            listing_url       scrape_id  \
# 0         11551     https://www.airbnb.com/rooms/11551  20201013023834
# 1         13913     https://www.airbnb.com/rooms/13913  20201013023834
# 2         15400     https://www.airbnb.com/rooms/15400  20201013023834
# 3         17402     https://www.airbnb.com/rooms/17402  20201013023834
# 4         17506     https://www.airbnb.com/rooms/17506  20201013023834
# ...         ...                                    ...             ...
# 76614  45844265  https://www.airbnb.com/rooms/45844265  20201013023834
# 76615  45844445  https://www.airbnb.com/rooms/45844445  20201013023834
# 76616  45845596  https://www.airbnb.com/rooms/45845596  20201013023834
# 76617  45845806  https://www.airbnb.com/rooms/45845806  20201013023834
# 76618  45845893  https://www.airbnb.com/rooms/45845893  20201013023834
#
#       last_scraped                                               name  \
# ...

# %%
amf_df.corrwith(amf_df.review_scores_rating)
# Out:
# reviews_per_month                              -0.001915
# calculated_host_listings_count_shared_rooms    -0.008486
# calculated_host_listings_count_private_rooms   -0.100026
# calculated_host_listings_count_entire_homes    -0.129267
# calculated_host_listings_count                 -0.143714
# review_scores_value                             0.686441
# review_scores_location                          0.366201
# review_scores_communication                     0.635034
# review_scores_checkin                           0.574393
# review_scores_cleanliness                       0.681657
# review_scores_accuracy                          0.714320
# review_scores_rating                            1.000000
# number_of_reviews_l30d                         -0.007916
# number_of_reviews_ltm                          -0.000526
# number_of_reviews                               0.012628
# availability_365                               -0.003877
# ...

# %%
x = '.'
x.is_digit()
# Out:
# ---------------------------------------------------------
# AttributeError          Traceback (most recent call last)
# <ipython-input-17-ab45cdb8a67f> in <module>
#       1 x = '.'
# ----> 2 x.is_digit()
#
# AttributeError: 'str' object has no attribute 'is_digit'
