# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

pd.set_option('display.max_columns', None)

# %%
def clean_listings(df):
    str_cols = ['bathrooms_text', 'price', 'room_type', 'property_type', 'neighbourhood_cleansed', 'name']
    irrelevant_cols = ['scrape_id', 'neighbourhood_group_cleansed', 'calendar_updated', 'license', 'bathrooms']
    
    numeric_df = df.copy().select_dtypes(include=np.number)
    numeric_df[str_cols] = df[str_cols]
    filtered_df = numeric_df.drop(columns=irrelevant_cols, axis=1, errors='ignore')
    
    return filtered_df[filtered_df.columns[::-1]]

# %%
# change paths to csv files on your local machine
# download large listings.csv.gz files
amf_df = clean_listings(pd.read_csv('amsterdam_data/listings_1.csv'))
atf_df = clean_listings(pd.read_csv('athens_data/listings.csv'))

# %%
report = ProfileReport(amf_df)
# Uncomment the following line to generate a pandas profile report (it might take some time with large datasets)
# report

# %%
amf_df
# Out:
#                                                     name  \
# 0               Quiet Garden View Room & Super Fast WiFi
# 1           Studio with private bathroom in the centre 1
# 2        Lovely apt in City Centre (w.lift) near Jordaan
# 3      Romantic, stylish B&B houseboat in canal district
# 4                                Comfortable double room
# ...                                                  ...
# 18777              Charming 1Room Apartment in Amsterdam
# 18778         clean and light apartment nearby the water
# 18779   A beautiful spacious room on a central location.
# 18780                                Studio in Amsterdam
# 18781             Spacious and cozy apartment in De Pijp
#
#                        neighbourhood_cleansed                property_type  \
# 0      Oostelijk Havengebied - Indische Buurt    Private room in apartment
# 1                                Centrum-Oost    Private room in townhouse
# 2                                Centrum-West             Entire apartment
# 3                                Centrum-West    Private room in houseboat
# 4                                Centrum-West    Private room in apartment
# ...                                       ...                          ...
# 18777                           Bos en Lommer             Entire apartment
# 18778                              Westerpark             Entire apartment
# 18779                 De Pijp - Rivierenbuurt  Private room in condominium
# 18780                         Watergraafsmeer             Entire apartment
# 18781                 De Pijp - Rivierenbuurt             Entire apartment
#
#              room_type    price    bathrooms_text  reviews_per_month  \
# 0         Private room   $59.00  1.5 shared baths               1.98
# 1         Private room  $236.00    1 private bath               2.63
# 2      Entire home/apt  $125.00            1 bath               0.15
# 3         Private room  $138.00         1.5 baths               2.05
# 4         Private room   $75.00     1 shared bath               2.72
# ...                ...      ...               ...                ...
# 18777  Entire home/apt  $137.00            1 bath                NaN
# 18778  Entire home/apt  $120.00         1.5 baths                NaN
# 18779     Private room   $20.00            1 bath                NaN
# 18780  Entire home/apt   $33.00         1.5 baths                NaN
# 18781  Entire home/apt  $105.00         1.5 baths                NaN
#
#        calculated_host_listings_count_shared_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 18777                                            0
# 18778                                            0
# 18779                                            0
# 18780                                            0
# 18781                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 1
# 1                                                 2
# 2                                                 0
# 3                                                 1
# 4                                                 2
# ...                                             ...
# 18777                                             0
# 18778                                             0
# 18779                                             2
# 18780                                             0
# 18781                                             0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 1                                                0
# 2                                                1
# 3                                                0
# 4                                                0
# ...                                            ...
# 18777                                            1
# 18778                                            2
# 18779                                            0
# 18780                                            1
# 18781                                            1
#
#        calculated_host_listings_count  review_scores_value  \
# 0                                   1                 10.0
# 1                                   2                  9.0
# 2                                   1                 10.0
# 3                                   1                 10.0
# 4                                   2                 10.0
# ...                               ...                  ...
# 18777                               1                  NaN
# 18778                               2                  NaN
# 18779                               2                  NaN
# 18780                               1                  NaN
# 18781                               1                  NaN
#
#        review_scores_location  review_scores_communication  \
# 0                         9.0                         10.0
# 1                        10.0                         10.0
# 2                        10.0                         10.0
# 3                        10.0                         10.0
# 4                        10.0                         10.0
# ...                       ...                          ...
# 18777                     NaN                          NaN
# 18778                     NaN                          NaN
# 18779                     NaN                          NaN
# 18780                     NaN                          NaN
# 18781                     NaN                          NaN
#
#        review_scores_checkin  review_scores_cleanliness  \
# 0                       10.0                       10.0
# 1                       10.0                       10.0
# 2                       10.0                       10.0
# 3                       10.0                       10.0
# 4                       10.0                       10.0
# ...                      ...                        ...
# 18777                    NaN                        NaN
# 18778                    NaN                        NaN
# 18779                    NaN                        NaN
# 18780                    NaN                        NaN
# 18781                    NaN                        NaN
#
#        review_scores_accuracy  review_scores_rating  number_of_reviews_l30d  \
# 0                        10.0                  98.0                       0
# 1                        10.0                  89.0                       0
# 2                        10.0                 100.0                       0
# 3                        10.0                  99.0                       0
# 4                        10.0                  97.0                       2
# ...                       ...                   ...                     ...
# 18777                     NaN                   NaN                       0
# 18778                     NaN                   NaN                       0
# 18779                     NaN                   NaN                       0
# 18780                     NaN                   NaN                       0
# 18781                     NaN                   NaN                       0
#
#        number_of_reviews_ltm  number_of_reviews  availability_365  \
# 0                          6                278                 0
# 1                         48                340                 0
# 2                          2                  5                58
# 3                         16                219               158
# 4                         32                336               340
# ...                      ...                ...               ...
# 18777                      0                  0               339
# 18778                      0                  0                51
# 18779                      0                  0                 0
# 18780                      0                  0                15
# 18781                      0                  0               253
#
#        availability_90  availability_60  availability_30  \
# 0                    0                0                0
# 1                    0                0                0
# 2                    4                0                0
# 3                   75               51               21
# 4                   82               56               28
# ...                ...              ...              ...
# 18777               74               51               25
# 18778               51               51               29
# 18779                0                0                0
# 18780               15               15               15
# 18781               61               38                8
#
#        maximum_nights_avg_ntm  minimum_nights_avg_ntm  maximum_maximum_nights  \
# 0                      1125.0                     3.0                    1125
# 1                       250.7                     4.0                     365
# 2                       180.0                    14.0                     180
# 3                      1125.0                     2.0                    1125
# 4                      1825.0                     2.0                    1825
# ...                       ...                     ...                     ...
# 18777                   365.0                     1.0                     365
# 18778                    60.0                     5.0                      60
# 18779                    30.0                     1.0                      30
# 18780                  1125.0                    10.0                    1125
# 18781                  1125.0                     7.0                    1125
#
#        minimum_maximum_nights  maximum_minimum_nights  minimum_minimum_nights  \
# 0                        1125                       3                       3
# 1                          60                       4                       4
# 2                         180                      14                      14
# 3                        1125                       2                       2
# 4                        1825                       2                       2
# ...                       ...                     ...                     ...
# 18777                     365                       1                       1
# 18778                      60                       5                       5
# 18779                      30                       1                       1
# 18780                    1125                      10                      10
# 18781                    1125                       7                       7
#
#        maximum_nights  minimum_nights  beds  bedrooms  accommodates  \
# 0                1125               3   2.0       1.0             2
# 1                 365               1   1.0       1.0             2
# 2                 180              14   1.0       1.0             3
# 3                 730               2   1.0       1.0             2
# 4                1825               2   1.0       1.0             2
# ...               ...             ...   ...       ...           ...
# 18777             365               1   2.0       1.0             4
# 18778              60               5   0.0       2.0             1
# 18779              30               1   1.0       1.0             2
# 18780              14              10   0.0       1.0             2
# 18781            1125               7   1.0       1.0             2
#
#        longitude  latitude  host_total_listings_count  host_listings_count  \
# 0        4.94142  52.36575                        1.0                  1.0
# 1        4.89396  52.36424                        2.0                  2.0
# 2        4.88339  52.37297                        2.0                  2.0
# 3        4.89188  52.38761                        1.0                  1.0
# 4        4.89092  52.36719                        2.0                  2.0
# ...          ...       ...                        ...                  ...
# 18777    4.84941  52.37642                      892.0                892.0
# 18778    4.88204  52.39042                        2.0                  2.0
# 18779    4.89995  52.34306                        3.0                  3.0
# 18780    4.91878  52.34885                        0.0                  0.0
# 18781    4.89740  52.35380                        1.0                  1.0
#
#          host_id        id
# 0           3159      2818
# 1          59484     20168
# 2          56142     25428
# 3          97647     27886
# 4         124245     28871
# ...          ...       ...
# 18777  310835509  45761390
# 18778     961670  45763935
# 18779   48168060  45776325
# 18780   75268907  45777642
# 18781  371160113  45783000
#
# [18782 rows x 42 columns]
